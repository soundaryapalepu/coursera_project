# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Objectives:
# * Python
# * SQL
# * Java
# * C++
# * JavaScript

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. Scala
# 4. SQL
# 5. PHP
# 6. Java

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. NumPy
# 3. Seaborn
# 4. Matplotlib
# 5. Pytorch
# 6. keras

# %% [markdown]
# | Data Science Tools |
# | ----:|
# | Jupyter |
# | RStdio |
# | Spyder |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# >This a simple arithmetic expression to mutiply then add integers

# %%
(3*4)+5
# Out:
# 17

# %%
#  This will convert 200 minutes to hours by diving by 60
def convert_mins_to_hrs(min):
   hour = min/60
   rem = min%60
   return "%02d hours and %02d minutes" % (hour, rem)
   
   

n = 200
print("Time in hours -",convert_mins_to_hrs(n))
# Out:
# Time in hours - 03 hours and 20 minutes

# %% [markdown]
# ## Soundarya Palepu
